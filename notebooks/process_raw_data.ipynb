# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path_csv_kick = os.path.join('../data/raw/kickstarter_csvs','Kickstarter_2018-02-15')
path_csv_indi = os.path.join('../data/raw/indiegogo_csvs','Indiegogo_2018-02-16')

# %%
data_csv_kick = pd.read_csv(os.path.join(path_csv_kick,'Kickstarter.csv'), parse_dates=['deadline'],infer_datetime_format=True)
data_csv_indi = pd.read_csv(os.path.join(path_csv_indi,'Indiegogo.csv'), parse_dates=['close_date'],infer_datetime_format=True)

# %%
len(data_csv_kick.dtypes), len(data_csv_indi.dtypes)
# Out:
# (37, 22)

# %%
data_csv_indi[['project_id','open_date','close_date','tagline','funds_raised_percent']]
# Out:
#        project_id                  open_date                 close_date  \
# 0          248794  2013-03-10T14:48:15-07:00  2013-05-10T23:59:59-07:00
# 1          472439  2013-07-22T16:56:59-07:00  2013-08-08T23:59:59-07:00
# 2          513287  2013-10-01T14:15:57-07:00  2013-10-26T23:59:59-07:00
# 3          866783  2014-09-16T06:54:31-07:00  2014-10-16T23:59:59-07:00
# 4          325793  2013-01-31T00:03:01-08:00  2013-03-01T23:59:59-08:00
# 5          618504  2014-01-03T16:27:27-08:00  2014-02-16T23:59:59-08:00
# 6         2336824  2018-02-07T20:07:42-08:00  2018-03-09T23:59:59-08:00
# 7          435725  2013-06-17T10:37:24-07:00  2013-08-16T23:59:59-07:00
# 8          449150  2013-06-26T17:28:01-07:00  2013-07-15T23:59:59-07:00
# 9          556754  2013-11-29T09:42:04-08:00  2014-01-17T23:59:59-08:00
# 10        1506082  2015-10-25T13:10:34-07:00  2015-11-24T23:59:59-08:00
# 11         375054  2013-04-05T09:23:09-07:00  2013-04-25T23:59:59-07:00
# ...

# %%
data_csv_indi.dtypes
# Out:
# bullet_point            object
# category                object
# category_url            object
# clickthrough_url        object
# close_date              object
# currency                object
# funds_raised_amount     object
# funds_raised_percent    object
# image_url               object
# is_indemand               bool
# is_pre_launch           object
# offered_by              object
# open_date               object
# price_offered           object
# price_retail            object
# product_id              object
# product_stage           object
# project_id               int64
# project_type            object
# source_url              object
# tagline                 object
# title                   object
# dtype: object

# %%
type(data_csv_indi.funds_raised_amount)
# Out:
# pandas.core.series.Series

# %%
data_csv_kick.deadline
# Out:
# 0       1334866560
# 1       1334959598
# 2       1334635140
# 3       1336440145
# 4       1333421843
# 5       1338175739
# 6       1334806096
# 7       1335584240
# 8       1336090320
# 9       1334030340
# 10      1338231398
# 11      1334606400
# 12      1335671940
# 13      1336736610
# 14      1335443088
# 15      1334593200
# 16      1334705215
# 17      1335068240
# 18      1335718137
# 19      1335552097
# 20      1336417291
# 21      1335758400
# 22      1335559247
# 23      1335561228
# 24      1331971953
# 25      1329498000
# 26      1330660740
# 27      1332727200
# 28      1332021858
# 29      1332110466
#            ...
# 4060    1377377970
# 4061    1378270740
# 4062    1379012983
# 4063    1379379620
# 4064    1372694400
# 4065    1374249600
# 4066    1374250417
# 4067    1374439180
# 4068    1374598820
# 4069    1374691562
# 4070    1376357694
# 4071    1374789600
# 4072    1375833540
# 4073    1375896068
# 4074    1375214742
# 4075    1376103148
# ...

# %%
df_csv_2.goal.describe(), df_csv_2.pledged.describe()
# Out:
# (count    4.074000e+03
#  mean     1.741602e+04
#  std      1.239223e+05
#  min      1.000000e+00
#  25%      1.500000e+03
#  50%      3.700000e+03
#  75%      8.700000e+03
#  max      5.000000e+06
#  Name: goal, dtype: float64, count      4074.000000
#  mean       3849.553397
#  std        9932.237684
#  min           0.000000
#  25%           8.500000
#  50%        1000.000000
#  75%        4357.250000
#  max      194635.650000
#  Name: pledged, dtype: float64)

# %%
import datetime
datetime.__doc__
datetime.datetime.fromtimestamp(int(df_csv_1['deadline'][4060])).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2013-08-24 16:59:30'

# %%
datetime.__doc__
# Out:
# 'Fast implementation of the datetime type.'

# %%
data_csv_kick.deadline.shape
# Out:
# (4090,)

# %%
sorted([datetime.datetime.fromtimestamp(int(deadline)).strftime('%Y-%m-%d %H:%M:%S') for deadline in data_csv_kick.deadline], reverse=True)
# Out:
# ['2018-04-15 23:59:00',
#  '2018-04-14 23:21:07',
#  '2018-04-14 09:37:34',
#  '2018-04-13 17:45:57',
#  '2018-04-12 17:56:44',
#  '2018-04-09 21:20:48',
#  '2018-04-09 14:55:48',
#  '2018-04-09 14:54:34',
#  '2018-04-07 17:17:09',
#  '2018-04-06 19:00:47',
#  '2018-04-06 18:00:00',
#  '2018-04-06 15:28:00',
#  '2018-04-05 18:24:25',
#  '2018-04-05 12:51:57',
#  '2018-04-04 14:16:00',
#  '2018-04-03 05:51:12',
#  '2018-04-02 02:59:00',
#  '2018-04-02 02:59:00',
#  '2018-04-01 03:29:58',
#  '2018-03-31 20:46:00',
#  '2018-03-31 20:37:00',
#  '2018-03-30 19:00:00',
#  '2018-03-30 04:40:27',
#  '2018-03-29 05:44:20',
#  '2018-03-28 20:32:56',
#  '2018-03-27 15:57:19',
#  '2018-03-27 14:59:47',
#  '2018-03-27 10:30:41',
#  '2018-03-26 16:15:34',
#  '2018-03-26 14:29:00',
#  '2018-03-24 11:59:50',
#  '2018-03-24 09:26:16',
#  '2018-03-23 17:15:27',
#  '2018-03-20 13:43:02',
#  '2018-03-20 07:02:41',
#  '2018-03-18 12:28:44',
#  '2018-03-18 10:49:02',
#  '2018-03-17 09:13:43',
# ...

# %%
sorted([datetime.datetime.fromtimestamp(deadline).strftime('%Y-%m-%d %H:%M:%S') for deadline in data_csv_indi.close_date], reverse=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-174-e1c40bbf3c6d> in <module>()
# ----> 1 sorted([datetime.datetime.fromtimestamp(deadline).strftime('%Y-%m-%d %H:%M:%S') for deadline in data_csv_indi.close_date], reverse=True)
#
# <ipython-input-174-e1c40bbf3c6d> in <listcomp>(.0)
# ----> 1 sorted([datetime.datetime.fromtimestamp(deadline).strftime('%Y-%m-%d %H:%M:%S') for deadline in data_csv_indi.close_date], reverse=True)
#
# TypeError: an integer is required (got type str)

# %%
pwd
# Out:
# '/Users/l2v/study/ds-projects/ds-crowdfunding/notebooks'
