# %%
import os
import sys
import pandas as pd

# %%
DATA_CSV = "../data/raw/csvs/"
# Out:
# '/Users/l2v/study/ds-projects/ds-crowdfunding/notebooks'

# %%
data_csv = pd.read_csv("Kickstarter.csv")

# %%
df_csv = pd.DataFrame(data_csv)

# %%
df_csv
# Out:
#       backers_count                                              blurb  \
# 0                 1  Monsters, Fantasy, Illusion, Delusion, and a h...
# 1                37  Nano Art will make and market customized piece...
# 2                81  Video and audio coverage of the MUTEK festival...
# 3                95              Finally, A Storyboard App Done Right!
# 4                10  If you like books and bookmarks, stick these s...
# 5                 0  WELCOME To... "HEART ART!" Enjoy the journey o...
# 6                 0  Standing on a bridge late at night, to home on...
# 7                46  Wearable electronics, poetry, theory and dance...
# 8                18  I will be drawing someone new every morning fo...
# 9                 3  I will be picking fairy tales and reading alou...
# 10                0  im an LA bedroom electronic musician. Id like ...
# 11               26  I am making a book of fake movie posters. Back...
# ...

# %%
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 2.0.2
